# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/catalyst_metric_learning_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/catalyst_metric_learning_defect

# %%
# !pip install -q timm wandb catalyst &> /dev/null
# !pip install -q hydra-core --upgrade &> /dev/null
# !pip uninstall accelerate 
# !pip install accelerate==0.15.0 &> /dev/null
# Out:
# Found existing installation: accelerate 0.16.0
# Uninstalling accelerate-0.16.0:
#   Would remove:
#     /usr/local/bin/accelerate
#     /usr/local/bin/accelerate-config
#     /usr/local/bin/accelerate-launch
#     /usr/local/lib/python3.8/dist-packages/accelerate-0.16.0.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/accelerate/*
# Proceed (Y/n)? Y
#   Successfully uninstalled accelerate-0.16.0

# %%
# !ls
# Out:
# config	log    notebooks  sanity_test.ipynb  src
# input	model  output	  sanity_test.py     submit

# %%
# !python sanity_test.py
# Out:
# /usr/local/lib/python3.8/dist-packages/catalyst/core/misc.py:119: UserWarning: No ``ICriterionCallback/CriterionCallback`` were found while runner.criterion is not None.Do you compute the loss during ``runner.handle_batch``?
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/catalyst/core/misc.py:127: UserWarning: No ``IBackwardCallback/BackwardCallback`` were found while runner.criterion/optimizer is not None.Do you backward the loss during ``runner.handle_batch``?
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/catalyst/core/misc.py:133: UserWarning: No ``IOptimizerCallback/OptimizerCallback`` were found while runner.optimizer is not None.Do run optimisation step pass during ``runner.handle_batch``?
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/catalyst/core/misc.py:139: UserWarning: No ``ISchedulerCallback/SchedulerCallback`` were found while runner.scheduler is not None.Do you make scheduler step during ``runner.handle_batch``?
#   warnings.warn(
# 1/50 * Epoch (train): 100% 50/50 [00:19<00:00,  2.53it/s, accuracy=0.750, f1_score=0.733, fbeta_score=0.732, loss=3.523, precision=0.750, recall=0.833]
# train (1/50) accuracy: 0.2700000000000001 | f1_score: 0.19485719835018803 | fbeta_score: 0.18704094974170635 | loss: 16.642990001039582 | precision: 0.32583337303581034 | recall: 0.2708333766120891
# 1/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 15.46it/s, accuracy=0.000e+00, f1_score=1.000e-07, fbeta_score=1.562e-07, loss=27.576, precision=0.500, recall=0.500]
# valid (1/50) accuracy: 0.4 | f1_score: 0.30095243777142344 | fbeta_score: 0.27697121439666544 | loss: 12.98937613070011 | precision: 0.6566666722297669 | recall: 0.5366666769981384
# * Epoch (1/50)
# 2/50 * Epoch (train): 100% 50/50 [00:19<00:00,  2.62it/s, accuracy=0.750, f1_score=0.733, fbeta_score=0.732, loss=8.204, precision=0.750, recall=0.833]
# train (2/50) accuracy: 0.7299999999999998 | f1_score: 0.6656190794706344 | fbeta_score: 0.6600080069899559 | loss: 4.017963158722288 | precision: 0.8083333459496497 | recall: 0.7408333459496497
# 2/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 15.61it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=1.318e-04, precision=1.000, recall=1.000]
# valid (2/50) accuracy: 0.8400000000000002 | f1_score: 0.7969524025917054 | fbeta_score: 0.8138658761978149 | loss: 1.90922215760831 | precision: 0.8400000095367433 | recall: 0.8966666746139527
# * Epoch (2/50)
# 3/50 * Epoch (train): 100% 50/50 [00:19<00:00,  2.62it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=1.431e-06, precision=1.000, recall=1.000]
# train (3/50) accuracy: 0.9349999999999999 | f1_score: 0.9070476293563844 | fbeta_score: 0.9060952311754226 | loss: 0.7130557770160586 | precision: 0.93833333671093 | recall: 0.9325000077486041
# 3/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 15.27it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (3/50) accuracy: 0.9599999999999999 | f1_score: 0.9573333358764647 | fbeta_score: 0.9571717262268066 | loss: 0.7898273016878465 | precision: 0.9599999999999999 | recall: 0.9733333396911621
# * Epoch (3/50)
# 4/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.64it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=8.047e-07, precision=1.000, recall=1.000]
# train (4/50) accuracy: 0.915 | f1_score: 0.8862857270240784 | fbeta_score: 0.8924843275547029 | loss: 1.3486153094918638 | precision: 0.9250000071525571 | recall: 0.9233333396911622
# 4/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 15.12it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (4/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 4.012520011826837e-06 | precision: 1.0 | recall: 1.0
# * Epoch (4/50)
# 5/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.65it/s, accuracy=0.750, f1_score=0.429, fbeta_score=0.469, loss=5.352, precision=0.500, recall=0.875]
# train (5/50) accuracy: 0.9149999999999999 | f1_score: 0.8700952535867692 | fbeta_score: 0.8698442113399506 | loss: 1.7392472871733302 | precision: 0.9233333384990692 | recall: 0.9191666734218598
# 5/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.80it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (5/50) accuracy: 0.9199999999999999 | f1_score: 0.8902857255935668 | fbeta_score: 0.899895396232605 | loss: 1.2947622222815605 | precision: 0.9133333444595337 | recall: 0.936666669845581
# * Epoch (5/50)
# 6/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.68it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=4.470e-07, precision=1.000, recall=1.000]
# train (6/50) accuracy: 0.8799999999999998 | f1_score: 0.8503809678554535 | fbeta_score: 0.8630190747976305 | loss: 1.665278086286716 | precision: 0.8941666734218597 | recall: 0.9141666722297669
# 6/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 15.02it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (6/50) accuracy: 0.98 | f1_score: 0.9542857217788696 | fbeta_score: 0.9575000047683716 | loss: 0.15386281467261143 | precision: 0.9600000047683716 | recall: 0.99
# * Epoch (6/50)
# 7/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.66it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (7/50) accuracy: 0.975 | f1_score: 0.9672380983829497 | fbeta_score: 0.9689697808027267 | loss: 0.2090934477079474 | precision: 0.9825000023841859 | recall: 0.9716666686534882
# 7/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 15.05it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (7/50) accuracy: 0.96 | f1_score: 0.9329523897171021 | fbeta_score: 0.936085867881775 | loss: 0.7358472139779654 | precision: 0.9400000047683715 | recall: 0.9766666698455809
# * Epoch (7/50)
# 8/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.65it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (8/50) accuracy: 0.95 | f1_score: 0.9344761967658998 | fbeta_score: 0.9375811791419982 | loss: 0.8080977273202832 | precision: 0.9433333373069764 | recall: 0.9650000047683716
# 8/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.87it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (8/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 0.013689666408026824 | precision: 1.0 | recall: 1.0
# * Epoch (8/50)
# 9/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.68it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=8.941e-08, precision=1.000, recall=1.000]
# train (9/50) accuracy: 0.9799999999999999 | f1_score: 0.9725714313983919 | fbeta_score: 0.974323315024376 | loss: 0.11019560770816358 | precision: 0.9875000023841859 | recall: 0.9750000011920928
# 9/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.71it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (9/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 2.965881180330143e-06 | precision: 1.0 | recall: 1.0
# * Epoch (9/50)
# 10/50 * Epoch (train): 100% 50/50 [00:19<00:00,  2.58it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (10/50) accuracy: 0.9899999999999999 | f1_score: 0.9893333339691162 | fbeta_score: 0.9901226568222048 | loss: 0.059442330173811224 | precision: 0.9916666674613953 | recall: 0.9916666674613951
# 10/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.63it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (10/50) accuracy: 0.9800000000000001 | f1_score: 0.9786666679382324 | fbeta_score: 0.9785858631134033 | loss: 0.12958679376445842 | precision: 0.9800000000000001 | recall: 0.986666669845581
# * Epoch (10/50)
# 11/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.66it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (11/50) accuracy: 0.9550000000000001 | f1_score: 0.933714293241501 | fbeta_score: 0.9355324554443356 | loss: 0.4508371039983581 | precision: 0.9600000035762787 | recall: 0.9525000047683715
# 11/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.98it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (11/50) accuracy: 0.96 | f1_score: 0.9329523897171019 | fbeta_score: 0.9360858678817748 | loss: 0.2946240663528441 | precision: 0.9400000047683716 | recall: 0.9766666698455811
# * Epoch (11/50)
# 12/50 * Epoch (train): 100% 50/50 [00:19<00:00,  2.53it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (12/50) accuracy: 0.9600000000000001 | f1_score: 0.932952389717102 | fbeta_score: 0.9356145250797274 | loss: 0.6095366508778843 | precision: 0.9600000047683712 | recall: 0.9566666698455814
# 12/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.95it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (12/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 1.4305111335488618e-08 | precision: 1.0 | recall: 1.0
# * Epoch (12/50)
# 13/50 * Epoch (train): 100% 50/50 [00:19<00:00,  2.60it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (13/50) accuracy: 0.9949999999999999 | f1_score: 0.9946666669845582 | fbeta_score: 0.9954761910438538 | loss: 0.14004569690468782 | precision: 0.9966666674613953 | recall: 0.9949999999999999
# 13/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.63it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (13/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 0.011198244639283528 | precision: 1.0 | recall: 1.0
# * Epoch (13/50)
# 14/50 * Epoch (train): 100% 50/50 [00:19<00:00,  2.62it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=1.490e-07, precision=1.000, recall=1.000]
# train (14/50) accuracy: 0.94 | f1_score: 0.9130476295948027 | fbeta_score: 0.912033735513687 | loss: 0.9950309638779508 | precision: 0.9550000023841857 | recall: 0.939166671037674
# 14/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.64it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (14/50) accuracy: 0.98 | f1_score: 0.9786666679382325 | fbeta_score: 0.9785858631134033 | loss: 0.4062774533756257 | precision: 0.98 | recall: 0.9866666698455809
# * Epoch (14/50)
# 15/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.63it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=1.341e-05, precision=1.000, recall=1.000]
# train (15/50) accuracy: 0.9849999999999999 | f1_score: 0.9779047644138337 | fbeta_score: 0.9803273832798002 | loss: 0.2888532737160351 | precision: 0.9833333361148835 | recall: 0.9874999999999999
# 15/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.73it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (15/50) accuracy: 0.98 | f1_score: 0.9786666679382325 | fbeta_score: 0.9785858631134033 | loss: 0.2947243946076196 | precision: 0.98 | recall: 0.9866666698455809
# * Epoch (15/50)
# 16/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.66it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=3.731e-04, precision=1.000, recall=1.000]
# train (16/50) accuracy: 0.9799999999999999 | f1_score: 0.9725714313983918 | fbeta_score: 0.9749738490581512 | loss: 0.29170153704523716 | precision: 0.9783333361148833 | recall: 0.9841666674613953
# 16/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.84it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (16/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 0.005220352265168912 | precision: 1.0 | recall: 1.0
# * Epoch (16/50)
# 17/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.65it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=5.066e-07, precision=1.000, recall=1.000]
# train (17/50) accuracy: 0.9600000000000001 | f1_score: 0.9397142934799195 | fbeta_score: 0.9417523443698883 | loss: 0.3310942843699299 | precision: 0.9666666698455809 | recall: 0.9575000035762787
# 17/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.43it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (17/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 2.621352235649965e-05 | precision: 1.0 | recall: 1.0
# * Epoch (17/50)
# 18/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.66it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (18/50) accuracy: 0.98 | f1_score: 0.9664761948585509 | fbeta_score: 0.9680429339408875 | loss: 0.2912250118581667 | precision: 0.9700000023841859 | recall: 0.9883333349227905
# 18/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.76it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (18/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 0.000131924552597269 | precision: 1.0 | recall: 1.0
# * Epoch (18/50)
# 19/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.64it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (19/50) accuracy: 0.9849999999999999 | f1_score: 0.971809527873993 | fbeta_score: 0.9719162088632584 | loss: 0.2672807055695089 | precision: 0.9825000011920926 | recall: 0.9841666686534883
# 19/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.66it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (19/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 0.0009581555375439167 | precision: 1.0 | recall: 1.0
# * Epoch (19/50)
# 20/50 * Epoch (train): 100% 50/50 [00:19<00:00,  2.60it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (20/50) accuracy: 0.9899999999999998 | f1_score: 0.9893333339691162 | fbeta_score: 0.9892929315567018 | loss: 0.036514596254911304 | precision: 0.9899999999999998 | recall: 0.9933333349227906
# 20/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.64it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (20/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 1.2636164228752023e-07 | precision: 1.0 | recall: 1.0
# * Epoch (20/50)
# 21/50 * Epoch (train): 100% 50/50 [00:19<00:00,  2.62it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (21/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 8.441503159499318e-05 | precision: 1.0 | recall: 1.0
# 21/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.50it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (21/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 3.69546604019888e-07 | precision: 1.0 | recall: 1.0
# * Epoch (21/50)
# 22/50 * Epoch (train): 100% 50/50 [00:18<00:00,  2.67it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# train (22/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 6.736884242187101e-05 | precision: 1.0 | recall: 1.0
# 22/50 * Epoch (valid): 100% 13/13 [00:00<00:00, 14.48it/s, accuracy=1.000, f1_score=1.000, fbeta_score=1.000, loss=0.000e+00, precision=1.000, recall=1.000]
# valid (22/50) accuracy: 1.0 | f1_score: 1.0 | fbeta_score: 1.0 | loss: 3.194792640215382e-07 | precision: 1.0 | recall: 1.0
# * Epoch (22/50)
# Top models:
# model/pth/model.0012.pth	0.0000
# 100% 13/13 [00:00<00:00, 14.06it/s]
