# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/catalyst_metric_learning_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/catalyst_metric_learning_defect

# %%
# !pip install -q timm wandb catalyst &> /dev/null
# !pip install faiss-cpu faiss-gpu &> /dev/null
# !pip install -q hydra-core --upgrade &> /dev/null

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python inference.py --timm_name convnext_base \
                     --layer_name ArcFace \
                     --wandb_run_path insilicomab/catalyst-metric-learning-defective/kjhmelwc \
                     --image_size 224 \
                     --embedding_size 512 \
                     --k 10
# Out:
# 100% 100/100 [00:02<00:00, 46.57it/s]
